# %% [markdown]
# # Check TCdata360 Data Sources (if updated)

# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import datetime
import re
import io

# %matplotlib inline

# %%
date_today = datetime.date.today().isoformat()

# %%
tc_datasets = 'http://tcdata360-backend.worldbank.org/api/v1/datasets'
df_tc_datasets = pd.read_json(requests.get(tc_datasets).text)

# %%
df_answer_key = pd.read_csv('2017-07-28-Check-TC-Data-Update-Answer-Key.csv', encoding='latin-1')

# %%
df_answer_key.head()
# Out:
#                        slug                       title  \
# 0                itip_goods                 I-TIP Goods
# 1                itip_goods                 I-TIP Goods
# 2                     escap                       ESCAP
# 3     innovation_indicators  OECD Innovation Indicators
# 4  investing_across_borders    Investing Across Borders
#
#                       source_name  \
# 0                 WTO I-TIP Goods
# 1                 WTO I-TIP Goods
# 2                           ESCAP
# 3                            OECD
# 4  WBG - Investing Across Borders
#
#                                          source_link  \
# 0                        https://i-tip.wto.org/goods
# 1                        https://i-tip.wto.org/goods
# 2  http://data.worldbank.org/data-catalog/trade-c...
# 3  http://www.oecd.org/innovation/inno/inno-stats...
# 4                           http://iab.worldbank.org
#
#                                           legal_text  \
# 0                           World Trade Organization
# 1                           World Trade Organization
# 2                                   World Bank Group
# 3  Organization for Economic Co-operation and Dev...
# 4                                   World Bank Group
#
#                                           legal_link  id  \
# 0  https://www.wto.org/english/info_e/cont_e.htm#...  44
# 1  https://www.wto.org/english/info_e/cont_e.htm#...  44
# 2            http://www.worldbank.org/terms-datasets  45
# 3            http://www.oecd.org/termsandconditions/  46
# 4            http://www.worldbank.org/terms-datasets  47
#
#                                Dataset / sub-dataset Site Data Coverage  \
# 0  WTO Integrated Trade Intelligence Portal (I-TI...   tc     2005-2016
# 1   WTO Integrated Trade Intelligence Portal (I-TIP)   tc     2005-2016
# 2                         ESCAP Trade Costs Database   tc   1995 - 2015
# 3                         OECD Innovation Indicators   tc    2013, 2015
# 4                           Investing Across Borders   tc    2010, 2012
#
#   Start Year Latest Year
# 0       2005        2016
# 1       2005        2016
# 2       1995        2015
# 3       2013        2015
# 4       2010        2012

# %%
df_answer_key.columns
# Out:
# Index(['slug', 'title', 'source_name', 'source_link', 'legal_text',
#        'legal_link', 'id', 'Dataset / sub-dataset', 'Site', 'Data Coverage',
#        'Start Year', 'Latest Year'],
#       dtype='object')

# %% [markdown]
# Loop through all dataset IDs and generate key statistics per dataset:
# - number of unique countries
# - number of unique indicators
# - current start year, excluding 100% NULL columns
# - end start year, excluding 100% NULL columns
# - whole timeframe (as a list), excluding 100% NULL columns

# %% [markdown]
# ## Scratch

# %%
data_columns = ['title', 'id', 'number_of_unique_countries', 'number_of_unique_indicators', 'number_of_unique_subindicators',
               'start_year', 'end_year', 'timeframe']

# %%
tc_data_check = pd.DataFrame()

# %%
# for row in df_tc_datasets.index:
#     id_dataset = df_tc_datasets['id'].ix[row]
#     title_dataset = df_tc_datasets['title'].ix[row]

# %%
import random
id_dataset = random.choice(list(df_tc_datasets['id']))
dat_url = "http://tcdata360-backend.worldbank.org/api/v1/datasets/" + str(id_dataset) + "/dump.csv"
dat = requests.get(dat_url)
df_dat = pd.read_csv(io.StringIO(dat.text))

# %% [markdown]
# Drop all completely NULL columns and rows

# %%
df_dat.dropna(axis=1, how='all', inplace=True)
df_dat.dropna(axis=0, how='all', inplace=True)

# %% [markdown]
# Generate features

# %%
num_of_countries = len(df_dat['Country ISO3'].value_counts().index)
num_of_indicators = len(df_dat['Indicator'].value_counts().index)
num_of_subindicators = df_dat[['Indicator', 'Subindicator Type']].drop_duplicates().shape[0]

# %%
list_timeframe = [col for col in df_dat.columns if col not in ['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type']]
list_timeframe = sorted(list_timeframe)

# %%
start_year = list_timeframe[0]
end_year = list_timeframe[-1]

# %% [markdown]
# Compile all data

# %%
dataset_list = [title_dataset, id_dataset, num_of_countries, num_of_indicators, num_of_subindicators, start_year, end_year, list_timeframe]

# %%
df_temp = pd.DataFrame(dataset_list).T

# %%
tc_data_check = tc_data_check.append(pd.DataFrame(dataset_list).T)

# %%
tc_data_check.columns = data_columns

# %%
tc_data_check.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Compiling into loop

# %%
data_columns = ['title', 'id', 'number_of_unique_countries', 'number_of_unique_indicators', 'number_of_unique_subindicators',
               'start_year', 'end_year', 'timeframe']
tc_data_check = pd.DataFrame()

success_counter = 0
error_counter = 0
error_list = []
total_count = len(df_tc_datasets.index)

for row in df_tc_datasets.index:
    id_dataset = df_tc_datasets['id'].ix[row]
    title_dataset = df_tc_datasets['title'].ix[row]
    
    dat_url = "http://tcdata360-backend.worldbank.org/api/v1/datasets/" + str(id_dataset) + "/dump.csv"
    dat = requests.get(dat_url)
    df_dat = pd.read_csv(io.StringIO(dat.text))
    
    print(df_dat.columns) #for debugging
    
    #drop all completele NULL columns and rows
    df_dat.dropna(axis=1, how='all', inplace=True)
    df_dat.dropna(axis=0, how='all', inplace=True)
    
    try:
        # Generate features for checking
        num_of_countries = len(df_dat['Country ISO3'].value_counts().index)
        num_of_indicators = len(df_dat['Indicator'].value_counts().index)
        num_of_subindicators = df_dat[['Indicator', 'Subindicator Type']].drop_duplicates().shape[0]

        nondate_cols = ['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type', 'Partner', 'MRV', 'Product']
        list_timeframe = [col for col in df_dat.columns if col not in nondate_cols]
        list_timeframe = sorted(list_timeframe)
        start_year = list_timeframe[0]
        end_year = list_timeframe[-1]

        # compile all data
        dataset_list = [title_dataset, id_dataset, num_of_countries, num_of_indicators, num_of_subindicators, start_year, end_year, list_timeframe]
        print(dataset_list) #for debugging

        df_temp = pd.DataFrame(dataset_list).T
        tc_data_check = tc_data_check.append(pd.DataFrame(dataset_list).T)
        
    except:
        error_counter += 1
        error_list.append([title_dataset, id_dataset])
        continue
        
    success_counter += 1
    
    print("Done checking %d out of %d datasets." % (success_counter + error_counter, total_count))
    
# Clean up final dataframe
tc_data_check.columns = data_columns
tc_data_check.reset_index(drop=True, inplace=True)

print("Done with all %d datasets with %d successes and %d failures." % (total_count, success_counter, error_counter))
print("Failed datasets include %s" % str(error_list))
# Out:
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015'],
#       dtype='object')
# ['PEFA', 590, 71, 111, 111, '2005', '2015', ['2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']]
# Done checking 1 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016'],
#       dtype='object')
# ['Enterprise Surveys', 49, 147, 121, 121, '2002', '2016', ['2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016']]
# Done checking 2 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2007', '2010', '2012', '2014', '2016'],
#       dtype='object')
# ['Logistics Performance Index', 50, 167, 7, 20, '2007', '2016', ['2007', '2010', '2012', '2014', '2016']]
# Done checking 3 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '1996', '1998', '2000', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015'],
#       dtype='object')
# ['Worldwide Governance Indicators', 51, 205, 6, 30, '1996', '2015', ['1996', '1998', '2000', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']]
# Done checking 4 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2007-2008', '2008-2009', '2009-2010', '2010-2011', '2011-2012',
#        '2012-2013', '2013-2014', '2014-2015', '2015-2016', '2016-2017'],
#       dtype='object')
# ['World Economic Forum Global Competitiveness Index', 53, 151, 120, 240, '2007-2008', '2016-2017', ['2007-2008', '2008-2009', '2009-2010', '2010-2011', '2011-2012', '2012-2013', '2013-2014', '2014-2015', '2015-2016', '2016-2017']]
# Done checking 5 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2010'],
#       dtype='object')
# ['Public Investment Management', 147, 68, 17, 17, '2010', '2010', ['2010']]
# Done checking 6 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2009'],
#       dtype='object')
# ['Human Resource Management', 483, 7, 109, 109, '2009', '2009', ['2009']]
# Done checking 7 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2016'],
#       dtype='object')
# ['UNCTAD Cyberlaw Tracker', 512, 190, 4, 4, '2016', '2016', ['2016']]
# Done checking 8 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008'],
#       dtype='object')
# ['Pay and Employment', 479, 200, 13, 13, '1990', '2008', ['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008']]
# Done checking 9 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016'],
#       dtype='object')
# ['I-TIP Goods', 44, 141, 15, 30, '1990', '2016', ['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016']]
# Done checking 10 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2010', '2012', '2014', '2016'],
#       dtype='object')
# ['Women, Business and the Law', 48, 171, 142, 142, '2010', '2016', ['2010', '2012', '2014', '2016']]
# Done checking 11 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '1919', '1919-01', '1919Q1', '1919-02', '1919Q2', '1919-03',
#        ...
#        '2015-12', '2016-01', '2016Q1', '2016-02', '2016Q2', '2016-03',
#        '2016-04', '2016-05', '2016-06', '2016-07'],
#       dtype='object', length=1662)
# ['OECD Innovation Indicators', 46, 55, 19, 38, '1919', '2016Q2', ['1919', '1919-01', '1919-02', '1919-03', '1919-04', '1919-05', '1919-06', '1919-07', '1919-08', '1919-09', '1919-10', '1919-11', '1919-12', '1919Q1', '1919Q2', '1919Q3', '1919Q4', '1920', '1920-01', '1920-02', '1920-03', '1920-04', '1920-05', '1920-06', '1920-07', '1920-08', '1920-09', '1920-10', '1920-11', '1920-12', '1920Q1', '1920Q2', '1920Q3', '1920Q4', '1921', '1921-01', '1921-02', '1921-03', '1921-04', '1921-05', '1921-06', '1921-07', '1921-08', '1921-09', '1921-10', '1921-11', '1921-12', '1921Q1', '1921Q2', '1921Q3', '1921Q4', '1922', '1922-01', '1922-02', '1922-03', '1922-04', '1922-05', '1922-06', '1922-07', '1922-08', '1922-09', '1922-10', '1922-11', '1922-12', '1922Q1', '1922Q2', '1922Q3', '1922Q4', '1923', '1923-01', '1923-02', '1923-03', '1923-04', '1923-05', '1923-06', '1923-07', '1923-08', '1923-09', '1923-10', '1923-11', '1923-12', '1923Q1', '1923Q2', '1923Q3', '1923Q4', '1924', '1924-01', '1924-02', '1924-03', '1924-04', '1924-05', '1924-06', '1924-07', '1924-08', '1924-09', '1924-10', '1924-11', '1924-12', '1924Q1', '1924Q2', '1924Q3', '1924Q4', '1925', '1925-01', '1925-02', '1925-03', '1925-04', '1925-05', '1925-06', '1925-07', '1925-08', '1925-09', '1925-10', '1925-11', '1925-12', '1925Q1', '1925Q2', '1925Q3', '1925Q4', '1926', '1926-01', '1926-02', '1926-03', '1926-04', '1926-05', '1926-06', '1926-07', '1926-08', '1926-09', '1926-10', '1926-11', '1926-12', '1926Q1', '1926Q2', '1926Q3', '1926Q4', '1927', '1927-01', '1927-02', '1927-03', '1927-04', '1927-05', '1927-06', '1927-07', '1927-08', '1927-09', '1927-10', '1927-11', '1927-12', '1927Q1', '1927Q2', '1927Q3', '1927Q4', '1928', '1928-01', '1928-02', '1928-03', '1928-04', '1928-05', '1928-06', '1928-07', '1928-08', '1928-09', '1928-10', '1928-11', '1928-12', '1928Q1', '1928Q2', '1928Q3', '1928Q4', '1929', '1929-01', '1929-02', '1929-03', '1929-04', '1929-05', '1929-06', '1929-07', '1929-08', '1929-09', '1929-10', '1929-11', '1929-12', '1929Q1', '1929Q2', '1929Q3', '1929Q4', '1930', '1930-01', '1930-02', '1930-03', '1930-04', '1930-05', '1930-06', '1930-07', '1930-08', '1930-09', '1930-10', '1930-11', '1930-12', '1930Q1', '1930Q2', '1930Q3', '1930Q4', '1931', '1931-01', '1931-02', '1931-03', '1931-04', '1931-05', '1931-06', '1931-07', '1931-08', '1931-09', '1931-10', '1931-11', '1931-12', '1931Q1', '1931Q2', '1931Q3', '1931Q4', '1932', '1932-01', '1932-02', '1932-03', '1932-04', '1932-05', '1932-06', '1932-07', '1932-08', '1932-09', '1932-10', '1932-11', '1932-12', '1932Q1', '1932Q2', '1932Q3', '1932Q4', '1933', '1933-01', '1933-02', '1933-03', '1933-04', '1933-05', '1933-06', '1933-07', '1933-08', '1933-09', '1933-10', '1933-11', '1933-12', '1933Q1', '1933Q2', '1933Q3', '1933Q4', '1934', '1934-01', '1934-02', '1934-03', '1934-04', '1934-05', '1934-06', '1934-07', '1934-08', '1934-09', '1934-10', '1934-11', '1934-12', '1934Q1', '1934Q2', '1934Q3', '1934Q4', '1935', '1935-01', '1935-02', '1935-03', '1935-04', '1935-05', '1935-06', '1935-07', '1935-08', '1935-09', '1935-10', '1935-11', '1935-12', '1935Q1', '1935Q2', '1935Q3', '1935Q4', '1936', '1936-01', '1936-02', '1936-03', '1936-04', '1936-05', '1936-06', '1936-07', '1936-08', '1936-09', '1936-10', '1936-11', '1936-12', '1936Q1', '1936Q2', '1936Q3', '1936Q4', '1937', '1937-01', '1937-02', '1937-03', '1937-04', '1937-05', '1937-06', '1937-07', '1937-08', '1937-09', '1937-10', '1937-11', '1937-12', '1937Q1', '1937Q2', '1937Q3', '1937Q4', '1938', '1938-01', '1938-02', '1938-03', '1938-04', '1938-05', '1938-06', '1938-07', '1938-08', '1938-09', '1938-10', '1938-11', '1938-12', '1938Q1', '1938Q2', '1938Q3', '1938Q4', '1939', '1939-01', '1939-02', '1939-03', '1939-04', '1939-05', '1939-06', '1939-07', '1939-08', '1939-09', '1939-10', '1939-11', '1939-12', '1939Q1', '1939Q2', '1939Q3', '1939Q4', '1940', '1940-01', '1940-02', '1940-03', '1940-04', '1940-05', '1940-06', '1940-07', '1940-08', '1940-09', '1940-10', '1940-11', '1940-12', '1940Q1', '194 ...
# Done checking 12 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        'Partner', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014'],
#       dtype='object')
# ['ESCAP', 45, 192, 3, 3, '1995', '2014', ['1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014']]
# Done checking 13 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type', 'MRV',
#        '2011', '2014'],
#       dtype='object')
# ['WB: Financial Inclusion Index (Findex)', 66, 155, 6, 6, '2011', '2014', ['2011', '2014']]
# Done checking 14 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016'],
#       dtype='object')
# ['WEF GCI Most Problematic Factors', 71, 144, 15, 15, '2008', '2016', ['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016']]
# Done checking 15 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2012'],
#       dtype='object')
# ['Investing Across Borders', 47, 87, 23, 23, '2012', '2012', ['2012']]
# Done checking 16 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016'],
#       dtype='object')
# ['Doing Business', 52, 189, 65, 76, '2003', '2016', ['2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016']]
# Done checking 17 out of 76 datasets.
# C:\Users\mrpso\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        'Product', 'Partner', '1948', '1949', '1950', '1950-1960',
#        ...
#        '2014', '2014Q1', '2014Q2', '2014Q3', '2014Q4', '2015', '2015Q1',
#        '2015Q2', '2015Q3', '2015Q4'],
#       dtype='object', length=156)
# ['United Nations Conference on Trade and Development Statistics', 76, 207, 165, 323, '1948', '2015Q4', ['1948', '1949', '1950', '1950-1960', '1950-1970', '1950-1980', '1950-1990', '1950-2000', '1950-2010', '1951', '1952', '1953', '1954', '1955', '1956', '1957', '1958', '1959', '1960', '1960-1970', '1960-1980', '1960-1990', '1960-2000', '1960-2010', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1970-1980', '1970-1990', '1970-2000', '1970-2005', '1970-2010', '1971', '1972', '1973', '1974', '1975', '1975-2005', '1976', '1977', '1978', '1979', '1980', '1980-1985', '1980-1990', '1980-2000', '1980-2010', '1981', '1982', '1983', '1984', '1985', '1985-1990', '1985-2005', '1986', '1987', '1988', '1989', '1990', '1990-1995', '1990-2000', '1990-2010', '1991', '1992', '1993', '1994', '1995', '1995-2000', '1995-2005', '1996', '1997', '1998', '1999', '2000', '2000-2005', '2000-2007', '2000-2008', '2000-2010', '2001', '2002', '2003', '2003-2011', '2003-2012', '2004', '2005', '2005-2010', '2005Q1', '2005Q2', '2005Q3', '2005Q4', '2006', '2006Q1', '2006Q2', '2006Q3', '2006Q4', '2007', '2007Q1', '2007Q2', '2007Q3', '2007Q4', '2008', '2008-2011', '2008-2012', '2008Q1', '2008Q2', '2008Q3', '2008Q4', '2009', '2009Q1', '2009Q2', '2009Q3', '2009Q4', '2010', '2010-2014', '2010Q1', '2010Q2', '2010Q3', '2010Q4', '2011', '2011Q1', '2011Q2', '2011Q3', '2011Q4', '2012', '2012Q1', '2012Q2', '2012Q3', '2012Q4', '2013', '2013Q1', '2013Q2', '2013Q3', '2013Q4', '2014', '2014Q1', '2014Q2', '2014Q3', '2014Q4', '2015', '2015Q1', '2015Q2', '2015Q3', '2015Q4']]
# Done checking 18 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016'],
#       dtype='object')
# ['Global Entrepreneurship Monitor National Expert Survey', 58, 106, 12, 12, '2007', '2016', ['2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016']]
# Done checking 19 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014'],
#       dtype='object')
# ['Competitive Industrial Performance Index', 77, 142, 20, 20, '1990', '2014', ['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014']]
# Done checking 20 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2015', '2017'],
#       dtype='object')
# ['Travel & Tourism Competitiveness Index', 78, 145, 19, 38, '2015', '2017', ['2015', '2017']]
# Done checking 21 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        'Product', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013'],
#       dtype='object')
# ['Temporary Trade Barriers Database', 64, 32, 10, 20, '1990', '2013', ['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013']]
# Done checking 22 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2004', '2006', '2007', '2008', '2009', '2010', '2011'],
#       dtype='object')
# ['Global Integrity Index', 428, 94, 1358, 1358, '2004', '2011', ['2004', '2006', '2007', '2008', '2009', '2010', '2011']]
# Done checking 23 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016'],
#       dtype='object')
# ['Doing Business', 435, 179, 108, 108, '2004', '2016', ['2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016']]
# Done checking 24 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2015'],
#       dtype='object')
# ['Networked Readiness index', 511, 138, 2, 2, '2015', '2015', ['2015']]
# Done checking 25 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015'],
#       dtype='object')
# ['Ibrahim Index of African Governance', 589, 53, 12, 12, '2000', '2015', ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']]
# Done checking 26 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2016'],
#       dtype='object')
# ['I-TIP Services', 57, 159, 168, 168, '2016', '2016', ['2016']]
# Done checking 27 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2016'],
#       dtype='object')
# ['Citizen Engagement in Rulemaking', 63, 184, 7, 7, '2016', '2016', ['2016']]
# Done checking 28 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '1998', '2003', '2008', '2013'],
#       dtype='object')
# ['OECD Product Market Regulation Database', 68, 47, 29, 29, '1998', '2013', ['1998', '2003', '2008', '2013']]
# Done checking 29 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2012', '2015'],
#       dtype='object')
# ['Quality of Govt', 88, 128, 114, 114, '2012', '2015', ['2012', '2015']]
# Done checking 30 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2006Q1', '2006Q2', '2006Q3', '2006Q4', '2007Q1', '2007Q2', '2007Q3',
#        '2007Q4', '2008Q1', '2008Q2', '2008Q3', '2008Q4', '2009Q1', '2009Q2',
#        '2009Q3', '2009Q4', '2010Q1', '2010Q2', '2010Q3', '2010Q4', '2011Q1',
#        '2011Q2', '2011Q3', '2011Q4', '2012Q1', '2012Q2', '2012Q3', '2012Q4',
#        '2013Q1', '2013Q2', '2013Q3', '2013Q4', '2014Q1', '2014Q2', '2014Q3'],
#       dtype='object')
# ['Measuring Export Competitiveness', 73, 201, 5, 15, '2006Q1', '2014Q3', ['2006Q1', '2006Q2', '2006Q3', '2006Q4', '2007Q1', '2007Q2', '2007Q3', '2007Q4', '2008Q1', '2008Q2', '2008Q3', '2008Q4', '2009Q1', '2009Q2', '2009Q3', '2009Q4', '2010Q1', '2010Q2', '2010Q3', '2010Q4', '2011Q1', '2011Q2', '2011Q3', '2011Q4', '2012Q1', '2012Q2', '2012Q3', '2012Q4', '2013Q1', '2013Q2', '2013Q3', '2013Q4', '2014Q1', '2014Q2', '2014Q3']]
# Done checking 31 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2014'],
#       dtype='object')
# ['Environmental Performance Index', 80, 128, 4, 4, '2014', '2014', ['2014']]
# Done checking 32 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2016'],
#       dtype='object')
# ['Inter-Parliamentary Union', 495, 185, 74, 74, '2016', '2016', ['2016']]
# Done checking 33 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2008'],
#       dtype='object')
# ['Public Accountability Mechanisms Income and Disclosure', 145, 85, 199, 199, '2008', '2008', ['2008']]
# Done checking 34 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2010'],
#       dtype='object')
# ['Public Accountability Mechanisms Freedom of Information', 146, 86, 38, 38, '2010', '2010', ['2010']]
# Done checking 35 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2016'],
#       dtype='object')
# ['Global Indicators of Regulatory Governance', 429, 183, 88, 88, '2016', '2016', ['2016']]
# Done checking 36 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014'],
#       dtype='object')
# ['Fiscal Rules Dataset', 98, 88, 60, 60, '1987', '2014', ['1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014']]
# Done checking 37 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016'],
#       dtype='object')
# ['Country Policy and Institutional Assessments', 102, 85, 16, 16, '2005', '2016', ['2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016']]
# Done checking 38 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2006', '2008', '2010', '2012', '2014', '2016'],
#       dtype='object')
# ['Bertelsmann Transformation Index', 505, 128, 52, 52, '2006', '2016', ['2006', '2008', '2010', '2012', '2014', '2016']]
# Done checking 39 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2013-14', '2014', '2015'],
#       dtype='object')
# ['UPU', 510, 198, 4, 4, '2005', '2015', ['2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2013-14', '2014', '2015']]
# Done checking 40 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        'Product', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015'],
#       dtype='object')
# ['World Integrated Trade Solution', 55, 188, 15, 15, '1988', '2015', ['1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']]
# Done checking 41 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2011Q1', '2011Q2', '2011Q3', '2011Q4', '2012Q1', '2012Q2', '2012Q3',
#        '2012Q4', '2013Q1', '2013Q2', '2013Q3', '2013Q4', '2014Q1', '2014Q2',
#        '2014Q3', '2014Q4', '2015Q1', '2015Q2', '2015Q3', '2015Q4', '2016Q1'],
#       dtype='object')
# ['Timely Indicators of Entrepreneurship', 60, 21, 3, 3, '2011Q1', '2016Q1', ['2011Q1', '2011Q2', '2011Q3', '2011Q4', '2012Q1', '2012Q2', '2012Q3', '2012Q4', '2013Q1', '2013Q2', '2013Q3', '2013Q4', '2014Q1', '2014Q2', '2014Q3', '2014Q4', '2015Q1', '2015Q2', '2015Q3', '2015Q4', '2016Q1']]
# Done checking 42 out of 76 datasets.
# Index(['<?xml version="1.0" encoding="UTF-8"?>'], dtype='object')
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')
# ['World Economic Outlook', 72, 191, 14, 21, '1980', '2022', ['1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']]
# Done checking 43 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2014'],
#       dtype='object')
# ['WB: Financial Inclusion Index (Findex)', 509, 144, 2, 2, '2014', '2014', ['2014']]
# Done checking 44 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2017'],
#       dtype='object')
# ['Enabling the Business of Agriculture', 62, 62, 46, 54, '2017', '2017', ['2017']]
# Done checking 45 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2013', '2014', '2015', '2016'],
#       dtype='object')
# ['World Justice Project', 82, 113, 77, 77, '2013', '2016', ['2013', '2014', '2015', '2016']]
# Done checking 46 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2015', '2016'],
#       dtype='object')
# ['UNCTAD', 513, 137, 1, 2, '2015', '2016', ['2015', '2016']]
# Done checking 47 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016'],
#       dtype='object')
# ['Statistical Capacity', 87, 145, 29, 29, '2004', '2016', ['2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016']]
# Done checking 48 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2006', '2008', '2010', '2012', '2015'],
#       dtype='object')
# ['IBP Open Budget Index', 92, 102, 242, 242, '2006', '2015', ['2006', '2008', '2010', '2012', '2015']]
# Done checking 49 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014'],
#       dtype='object')
# ['Failed States Index', 97, 177, 11, 11, '2006', '2014', ['2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014']]
# Done checking 50 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016'],
#       dtype='object')
# ['World Development Indicators', 56, 217, 284, 284, '1960', '2016', ['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016']]
# Done checking 51 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '1996', '1998', '2000', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015'],
#       dtype='object')
# ['Worldwide Governance Indicators', 485, 205, 6, 6, '1996', '2015', ['1996', '1998', '2000', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']]
# Done checking 52 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        'Product', '2014', '2015', '2016'],
#       dtype='object')
# ['Services Trade Restrictiveness Index', 61, 44, 6, 6, '2014', '2016', ['2014', '2015', '2016']]
# Done checking 53 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2010', '2012', '2014', '2016'],
#       dtype='object')
# ['Women, Business and the Law', 84, 187, 132, 132, '2010', '2016', ['2010', '2012', '2014', '2016']]
# Done checking 54 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2006', '2008', '2010', '2012', '2014', '2016'],
#       dtype='object')
# ['Bertelsmann Transformation Index', 67, 128, 3, 3, '2006', '2016', ['2006', '2008', '2010', '2012', '2014', '2016']]
# Done checking 55 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015'],
#       dtype='object')
# ['Polity IV', 89, 78, 16, 16, '1987', '2015', ['1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']]
# Done checking 56 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        'Product', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011'],
#       dtype='object')
# ['World Input Output Database', 69, 39, 24, 24, '1995', '2011', ['1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011']]
# Done checking 57 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        'Partner', '1950', '1951', '1952', '1953', '1954',
#        ...
#        '2016M02', '2016Q2', '2016M03', '2016Q3', '2016M04', '2016M05',
#        '2016M06', '2016M07', '2016M08', '2016M09'],
#       dtype='object', length=979)
# ['Direction of Trade', 74, 180, 3, 3, '1950', '2016Q3', ['1950', '1951', '1952', '1953', '1954', '1955', '1956', '1957', '1958', '1959', '1960', '1960M01', '1960M02', '1960M03', '1960M04', '1960M05', '1960M06', '1960M07', '1960M08', '1960M09', '1960M10', '1960M11', '1960M12', '1960Q1', '1960Q2', '1960Q3', '1960Q4', '1961', '1961M01', '1961M02', '1961M03', '1961M04', '1961M05', '1961M06', '1961M07', '1961M08', '1961M09', '1961M10', '1961M11', '1961M12', '1961Q1', '1961Q2', '1961Q3', '1961Q4', '1962', '1962M01', '1962M02', '1962M03', '1962M04', '1962M05', '1962M06', '1962M07', '1962M08', '1962M09', '1962M10', '1962M11', '1962M12', '1962Q1', '1962Q2', '1962Q3', '1962Q4', '1963', '1963M01', '1963M02', '1963M03', '1963M04', '1963M05', '1963M06', '1963M07', '1963M08', '1963M09', '1963M10', '1963M11', '1963M12', '1963Q1', '1963Q2', '1963Q3', '1963Q4', '1964', '1964M01', '1964M02', '1964M03', '1964M04', '1964M05', '1964M06', '1964M07', '1964M08', '1964M09', '1964M10', '1964M11', '1964M12', '1964Q1', '1964Q2', '1964Q3', '1964Q4', '1965', '1965M01', '1965M02', '1965M03', '1965M04', '1965M05', '1965M06', '1965M07', '1965M08', '1965M09', '1965M10', '1965M11', '1965M12', '1965Q1', '1965Q2', '1965Q3', '1965Q4', '1966', '1966M01', '1966M02', '1966M03', '1966M04', '1966M05', '1966M06', '1966M07', '1966M08', '1966M09', '1966M10', '1966M11', '1966M12', '1966Q1', '1966Q2', '1966Q3', '1966Q4', '1967', '1967M01', '1967M02', '1967M03', '1967M04', '1967M05', '1967M06', '1967M07', '1967M08', '1967M09', '1967M10', '1967M11', '1967M12', '1967Q1', '1967Q2', '1967Q3', '1967Q4', '1968', '1968M01', '1968M02', '1968M03', '1968M04', '1968M05', '1968M06', '1968M07', '1968M08', '1968M09', '1968M10', '1968M11', '1968M12', '1968Q1', '1968Q2', '1968Q3', '1968Q4', '1969', '1969M01', '1969M02', '1969M03', '1969M04', '1969M05', '1969M06', '1969M07', '1969M08', '1969M09', '1969M10', '1969M11', '1969M12', '1969Q1', '1969Q2', '1969Q3', '1969Q4', '1970', '1970M01', '1970M02', '1970M03', '1970M04', '1970M05', '1970M06', '1970M07', '1970M08', '1970M09', '1970M10', '1970M11', '1970M12', '1970Q1', '1970Q2', '1970Q3', '1970Q4', '1971', '1971M01', '1971M02', '1971M03', '1971M04', '1971M05', '1971M06', '1971M07', '1971M08', '1971M09', '1971M10', '1971M11', '1971M12', '1971Q1', '1971Q2', '1971Q3', '1971Q4', '1972', '1972M01', '1972M02', '1972M03', '1972M04', '1972M05', '1972M06', '1972M07', '1972M08', '1972M09', '1972M10', '1972M11', '1972M12', '1972Q1', '1972Q2', '1972Q3', '1972Q4', '1973', '1973M01', '1973M02', '1973M03', '1973M04', '1973M05', '1973M06', '1973M07', '1973M08', '1973M09', '1973M10', '1973M11', '1973M12', '1973Q1', '1973Q2', '1973Q3', '1973Q4', '1974', '1974M01', '1974M02', '1974M03', '1974M04', '1974M05', '1974M06', '1974M07', '1974M08', '1974M09', '1974M10', '1974M11', '1974M12', '1974Q1', '1974Q2', '1974Q3', '1974Q4', '1975', '1975M01', '1975M02', '1975M03', '1975M04', '1975M05', '1975M06', '1975M07', '1975M08', '1975M09', '1975M10', '1975M11', '1975M12', '1975Q1', '1975Q2', '1975Q3', '1975Q4', '1976', '1976M01', '1976M02', '1976M03', '1976M04', '1976M05', '1976M06', '1976M07', '1976M08', '1976M09', '1976M10', '1976M11', '1976M12', '1976Q1', '1976Q2', '1976Q3', '1976Q4', '1977', '1977M01', '1977M02', '1977M03', '1977M04', '1977M05', '1977M06', '1977M07', '1977M08', '1977M09', '1977M10', '1977M11', '1977M12', '1977Q1', '1977Q2', '1977Q3', '1977Q4', '1978', '1978M01', '1978M02', '1978M03', '1978M04', '1978M05', '1978M06', '1978M07', '1978M08', '1978M09', '1978M10', '1978M11', '1978M12', '1978Q1', '1978Q2', '1978Q3', '1978Q4', '1979', '1979M01', '1979M02', '1979M03', '1979M04', '1979M05', '1979M06', '1979M07', '1979M08', '1979M09', '1979M10', '1979M11', '1979M12', '1979Q1', '1979Q2', '1979Q3', '1979Q4', '1980', '1980M01', '1980M02', '1980M03', '1980M04', '1980M05', '1980M06', '1980M07', '1980M08', '1980M09', '1980M10', '1980M11', '1980M12', '1980Q1', '1980Q2', '1980Q3', '1980Q4', '1981', '1981M01', '1981M02', '1981M03', '1981M04', '1981M05', '1981M06', '1981M07' ...
# Done checking 58 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        '2022', '2023', '2024', '2025', '2026', '2027'],
#       dtype='object')
# ['World Travel & Tourism Council', 79, 176, 12, 66, '1995', '2027', ['1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025', '2026', '2027']]
# Done checking 59 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object')
# ['Global Competitiveness Index', 430, 148, 108, 108, '2006', '2015', ['2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']]
# Done checking 60 out of 76 datasets.
# Index(['<?xml version="1.0" encoding="UTF-8"?>'], dtype='object')
# Index(['<?xml version="1.0" encoding="UTF-8"?>'], dtype='object')
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2010', '2011', '2015'],
#       dtype='object')
# ['ITU Database', 508, 185, 3, 4, '2010', '2015', ['2010', '2011', '2015']]
# Done checking 61 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2016'],
#       dtype='object')
# ['World Economic Forum', 514, 138, 1, 2, '2016', '2016', ['2016']]
# Done checking 62 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2013', '2014', '2015', '2016'],
#       dtype='object')
# ['Heritage Index of Economic Freedom', 54, 185, 11, 13, '2013', '2016', ['2013', '2014', '2015', '2016']]
# Done checking 63 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016'],
#       dtype='object')
# ['Global Entrepreneurship Monitor Adult Population Survey', 59, 107, 20, 20, '2001', '2016', ['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016']]
# Done checking 64 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2012', '2013', '2014', '2015', '2016'],
#       dtype='object')
# ['WEF: Global Information Technology Report', 65, 150, 67, 134, '2012', '2016', ['2012', '2013', '2014', '2015', '2016']]
# Done checking 65 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        'Product', '2011', '2012'],
#       dtype='object')
# ['Entrepreneurship at a Glance', 70, 34, 3, 13, '2011', '2012', ['2011', '2012']]
# Done checking 66 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        'Partner', '1995', '2000', '2005', '2008', '2009', '2010', '2011'],
#       dtype='object')
# ['Trade in Value Added', 75, 60, 41, 41, '1995', '2011', ['1995', '2000', '2005', '2008', '2009', '2010', '2011']]
# Done checking 67 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012'],
#       dtype='object')
# ['Sustainable Energy For All', 81, 184, 1, 1, '1990', '2012', ['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012']]
# Done checking 68 out of 76 datasets.
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2013', '2014'],
#       dtype='object')
# ['Corruption Perceptions Index', 85, 173, 1, 1, '2013', '2014', ['2013', '2014']]
# Done checking 69 out of 76 datasets.
# Index(['<?xml version="1.0" encoding="UTF-8"?>'], dtype='object')
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2014', '2015', '2016'],
#       dtype='object')
# ['Sustainable Governance Indicators', 86, 41, 117, 117, '2014', '2016', ['2014', '2015', '2016']]
# Done checking 70 out of 76 datasets.
# Index(['<?xml version="1.0" encoding="UTF-8"?>'], dtype='object')
# Index(['Country ISO3', 'Country Name', 'Indicator', 'Subindicator Type',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016'],
#       dtype='object')
# ['Enterprise Surveys', 99, 146, 118, 118, '2002', '2016', ['2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016']]
# Done checking 71 out of 76 datasets.
# Done with all 76 datasets with 71 successes and 0 failures.
# Failed datasets include []

# %%
tc_data_check.head()
# Out:
#                                                title   id  \
# 0                                               PEFA  590
# 1                                 Enterprise Surveys   49
# 2                        Logistics Performance Index   50
# 3                    Worldwide Governance Indicators   51
# 4  World Economic Forum Global Competitiveness Index   53
#
#   number_of_unique_countries number_of_unique_indicators  \
# 0                         71                         111
# 1                        147                         121
# 2                        167                           7
# 3                        205                           6
# 4                        151                         120
#
#   number_of_unique_subindicators start_year   end_year  \
# 0                            111       2005       2015
# 1                            121       2002       2016
# 2                             20       2007       2016
# 3                             30       1996       2015
# 4                            240  2007-2008  2016-2017
#
#                                            timeframe
# 0  [2005, 2006, 2007, 2008, 2009, 2010, 2011, 201...
# 1  [2002, 2003, 2004, 2005, 2006, 2007, 2008, 200...
# 2                     [2007, 2010, 2012, 2014, 2016]
# 3  [1996, 1998, 2000, 2002, 2003, 2004, 2005, 200...
# 4  [2007-2008, 2008-2009, 2009-2010, 2010-2011, 2...

# %% [markdown]
# # Merge against TC datasets

# %%
df_tc_data_check = df_tc_datasets[['slug', 'id', 'source','title']].merge(tc_data_check, how="outer", on=['id', 'title'])

# %% [markdown]
# ## Confirming if errors are valid

# %%
df_tc_data_check[df_tc_data_check['number_of_unique_countries'].isnull()]
# Out:
#           slug   id                                      source  \
# 42  ArabBarAll  104                               ArabBarometer
# 61        DAGI  101  Development, Aid and Governance Indicators
# 62  AfroBarAll  105                               AfroBarometer
# 72         GCB   96  Transparency - Global Corruption Barometer
# 74    LatinBar   90                             Latinobarometro
#
#                                          title number_of_unique_countries  \
# 42                               ArabBarometer                        NaN
# 61  Development, Aid and Governance Indicators                        NaN
# 62                               AfroBarometer                        NaN
# 72                 Global Corruption Barometer                        NaN
# 74                             Latinobarometro                        NaN
#
#    number_of_unique_indicators number_of_unique_subindicators start_year  \
# 42                         NaN                            NaN        NaN
# 61                         NaN                            NaN        NaN
# 62                         NaN                            NaN        NaN
# 72                         NaN                            NaN        NaN
# 74                         NaN                            NaN        NaN
#
#    end_year timeframe
# 42      NaN       NaN
# 61      NaN       NaN
# 62      NaN       NaN
# 72      NaN       NaN
# 74      NaN       NaN

# %% [markdown]
# ## Cleaning dates for comparison

# %%
def clean_up_dates(x):
    cleaned_date = x
    m = re.match('(\d{4})-(\d{4})', str(x))
    if m:
        cleaned_date = m.groups()[-1]
    else:
        n = re.match('(\d{4})Q\d{1}', str(x))
        if n:
            cleaned_date = n.groups()[-1]
        else:
            o = re.match('(\d{4})M\d{2}', str(x))
            if o:
                cleaned_date = o.groups()[-1]
    return cleaned_date

# %%
df_tc_data_check['start_year-clean'] = df_tc_data_check['start_year'].apply(lambda x: clean_up_dates(x))
df_tc_data_check['end_year-clean'] = df_tc_data_check['end_year'].apply(lambda x: clean_up_dates(x))

# %%
df_tc_data_check.head()
# Out:
#                               slug   id  \
# 0                             PEFA  590
# 1               enterprise_surveys   49
# 2      logistics_performance_index   50
# 3  worldwide_governance_indicators   51
# 4     global_competitiveness_index   53
#
#                                               source  \
# 0                                               PEFA
# 1                           WBG - Enterprise Surveys
# 2                  WBG - Logistics Performance Index
# 3                    Worldwide Governance Indicators
# 4  World Economic Forum Global Competitiveness Index
#
#                                                title  \
# 0                                               PEFA
# 1                                 Enterprise Surveys
# 2                        Logistics Performance Index
# 3                    Worldwide Governance Indicators
# 4  World Economic Forum Global Competitiveness Index
#
#   number_of_unique_countries number_of_unique_indicators  \
# 0                         71                         111
# 1                        147                         121
# 2                        167                           7
# 3                        205                           6
# 4                        151                         120
#
#   number_of_unique_subindicators start_year   end_year  \
# 0                            111       2005       2015
# 1                            121       2002       2016
# 2                             20       2007       2016
# 3                             30       1996       2015
# 4                            240  2007-2008  2016-2017
#
#                                            timeframe start_year-clean  \
# 0  [2005, 2006, 2007, 2008, 2009, 2010, 2011, 201...             2005
# 1  [2002, 2003, 2004, 2005, 2006, 2007, 2008, 200...             2002
# 2                     [2007, 2010, 2012, 2014, 2016]             2007
# 3  [1996, 1998, 2000, 2002, 2003, 2004, 2005, 200...             1996
# 4  [2007-2008, 2008-2009, 2009-2010, 2010-2011, 2...             2008
#
#   end_year-clean
# 0           2015
# 1           2016
# 2           2016
# 3           2015
# 4           2017

# %%
df_tc_data_check['id'] = df_tc_data_check['id'].astype(str)

# %%
df_merge = df_tc_data_check.merge(df_answer_key, how='outer', on=['id', 'slug', 'title'])

# %% [markdown]
# ## Removing datasets which are/have:
# - without data
# - new datasets (with data yet to be ingested)
# - duplicated (same slug as another's)

# %%
df_merge_shortlist = df_merge[['id', 'title', 'slug', 'Site', 'start_year-clean', 'end_year-clean', 'Start Year', 'Latest Year']].dropna(axis=0, how='any', subset=['id','start_year-clean','Start Year'])

# %%
df_merge_shortlist = df_merge_shortlist[(df_merge_shortlist['Start Year'] != 'N/A (duplicate dataset)') & (df_merge_shortlist['Start Year'] != 'N/A (too general)')]

# %%
df_merge_shortlist['start_year-check'] = df_merge_shortlist['start_year-clean'] <= df_merge_shortlist['Start Year']
df_merge_shortlist['end_year-check'] = df_merge_shortlist['end_year-clean'] >= df_merge_shortlist['Latest Year']

# %%
def amida_action(x):
    action = "Updated. No action required."
    
    end = x['end_year-check']
    start = x['start_year-check']
    
    if (not end) & (not start):
        action = "Not updated (both start and end dates)"
    elif end & (not start):
        action = "Not updated (start date only)"
    elif (not end) & (start):
        action = "Not updated (end date only)"
    
    if (x['Site'] == 'gv') & (action != "Updated. No action required."):
        action = "[Gov dataset - For Luis' action] "+ action
    
    return action

# %%
df_merge_shortlist
# Out:
#      id                                              title  \
# 0   590                                               PEFA
# 2    50                        Logistics Performance Index
# 5   147                       Public Investment Management
# 6   483                          Human Resource Management
# 7   512                            UNCTAD Cyberlaw Tracker
# 8   479                                 Pay and Employment
# 9    44                                        I-TIP Goods
# 10   44                                        I-TIP Goods
# 12   46                         OECD Innovation Indicators
# 13   45                                              ESCAP
# 15   71                   WEF GCI Most Problematic Factors
# 16   47                           Investing Across Borders
# 19   58  Global Entrepreneurship Monitor National Exper...
# 20   77           Competitive Industrial Performance Index
# 21   78             Travel & Tourism Competitiveness Index
# 22   64                  Temporary Trade Barriers Database
# 23  428                             Global Integrity Index
# 24  435                                     Doing Business
# 25  511                          Networked Readiness index
# 26  589                Ibrahim Index of African Governance
# 27   57                                     I-TIP Services
# 29   68            OECD Product Market Regulation Database
# 30   88                                    Quality of Govt
# 31   73                   Measuring Export Competitiveness
# 32   80                    Environmental Performance Index
# 33  495                          Inter-Parliamentary Union
# 34  145  Public Accountability Mechanisms Income and Di...
# 35  146  Public Accountability Mechanisms Freedom of In...
# 36  429         Global Indicators of Regulatory Governance
# 37   98                               Fiscal Rules Dataset
# 38  102       Country Policy and Institutional Assessments
# 39  505                   Bertelsmann Transformation Index
# 40  510                                                UPU
# 41   55                    World Integrated Trade Solution
# 42   60              Timely Indicators of Entrepreneurship
# 44   72                             World Economic Outlook
# 45  509             WB: Financial Inclusion Index (Findex)
# 47   82                              World Justice Project
# 49   87                               Statistical Capacity
# 50   92                              IBP Open Budget Index
# 51   97                                Failed States Index
# 52   56                       World Development Indicators
# 53  485                    Worldwide Governance Indicators
# 54   61               Services Trade Restrictiveness Index
# 55   84                        Women, Business and the Law
# 57   89                                          Polity IV
# 58   69                        World Input Output Database
# 59   74                                 Direction of Trade
# 60   79                     World Travel & Tourism Council
# 61  430                       Global Competitiveness Index
# 64  508                                       ITU Database
# 66   54                 Heritage Index of Economic Freedom
# 67   59  Global Entrepreneurship Monitor Adult Populati...
# 68   65          WEF: Global Information Technology Report
# 69   70                       Entrepreneurship at a Glance
# 70   75                               Trade in Value Added
# 71   81                         Sustainable Energy For All
# 72   85                       Corruption Perceptions Index
# 74   86                  Sustainable Governance Indicators
# 76   99                                 Enterprise Surveys
#
#                                                slug  Site start_year-clean  \
# 0                                              PEFA    gv             2005
# 2                       logistics_performance_index    tc             2007
# 5                                               PIM    gv             2010
# 6                                               HRM    gv             2009
# 7                           UNCTAD Cyberlaw Tracker    tc             2016
# 8                                           PAY_EMP    gv             1990
# 9                                        itip_goods    tc             1990
# 10                                       itip_goods    tc             1990
# 12                            innovation_indicators    tc             1919
# 13                                            escap    tc             1995
# 15                         most_problematic_factors    tc             2008
# 16                         investing_across_borders    tc             2012
# 19                           national_expert_survey    tc             2007
# 20               competitive_industrial_performance    tc             1990
# 21                   travel_tourism_competitiveness    tc             2015
# 22                         temporary_trade_barriers    tc             1990
# 23                                 Global_Integrity    gv             2004
# 24                                               DB  both             2004
# 25  Networked Readiness Index, World Economic Forum    tc             2015
# 26                                             IIAG    gv             2000
# 27                                    itip_services    tc             2016
# 29                        product_market_regulation    tc             1998
# 30                                              QOG    gv             2012
# 31                 measuring_export_competitiveness    tc             2006
# 32                  environmental_performance_index    tc             2014
# 33                                              IPU    gv             2016
# 34                                          PAM_IAD    gv             2008
# 35                                              PAM    gv             2010
# 36                                Global_Indicators    gv             2016
# 37                                           FAD_FR    gv             1987
# 38                                             CPIA  both             2005
# 39                                              BTI  both             2006
# 40                                              UPU    tc             2005
# 41                                             wits    tc             1988
# 42            timely_indicators_of_entrepreneurship    tc             2011
# 44                           world_economic_outlook    tc             1980
# 45                   Global Findex 2014, World Bank    tc             2014
# 47                                              WJP    gv             2013
# 49                                               SC    gv             2004
# 50                                              IBP    gv             2006
# 51                                              FSI    gv             2006
# 52                     world_development_indicators    tc             1960
# 53                                              WGI  both             1996
# 54                                             stri    tc             2014
# 55                                              WBL  both             2010
# 57                                              PIV    gv             1987
# 58                                             wiod    tc             1995
# 59                               direction_of_trade    tc             1950
# 60                     world_travel_tourism_council    tc             1995
# 61                                              GCI  both             2006
# 64                                     ITU Database    tc             2010
# 66               heritage_index_of_economic_freedom    tc             2013
# 67                          adult_population_survey    tc             2001
# 68             global_information_technology_report    tc             2012
# 69                     entrepreneurship_at_a_glance    tc             2011
# 70                                             tiva    tc             1995
# 71                       sustainable_energy_for_all    tc             1990
# 72                                               TI    gv             2013
# 74                                              SGI    gv             2014
# 76                                               ES  both             2002
#
#    end_year-clean               Start Year        Latest Year  \
# 0            2015                     2005               2016
# 2            2016                     2007               2016
# 5            2010                     1987               2016
# 6            2009                     1987               2016
# 7            2016                     2016               2016
# 8            2008                     1987               2016
# 9            2016                     2005               2016
# 10           2016                     2005               2016
# 12           2016                     2013               2015
# 13           2014                     1995               2015
# 15           2016                     2007               2016
# 16           2012                     2010               2012
# 19           2016                     2007               2016
# 20           2014                     1990               2015
# 21           2017                     2015               2017
# 22           2013                     1980               2015
# 23           2011                     2004               2011
# 24           2016                     2004               2016
# 25           2015                     2001               2016
# 26           2015                     2000               2015
# 27           2016  2009/2011/2014 (varies)               2016
# 29           2013                     1998               2013
# 30           2015                     2008               2012
# 31           2014                     2006               2016
# 32           2014                     2006               2016
# 33           2016                     1997               2017
# 34           2008                     1987               2016
# 35           2010                     1987               2016
# 36           2016                     2015               2016
# 37           2014                     1985               2015
# 38           2016                     2005               2016
# 39           2016                     2006               2016
# 40           2015                     1980               2015
# 41           2015                     1988               2015
# 42           2016                     2007               2017
# 44           2022                     1980  2018 (projection)
# 45           2014                     2011               2014
# 47           2016                     2012               2016
# 49           2016                     2004               2016
# 50           2015                     2006               2017
# 51           2014                     2006               2017
# 52           2016                     1960               2016
# 53           2015                     1996               2015
# 54           2016                     2014               2016
# 55           2016                     2010               2016
# 57           2015                     1800               2015
# 58           2011                     1995               2014
# 59           2016                     1948               2016
# 60           2027                     2006               2016
# 61           2015                     2007               2016
# 64           2015                     2000               2016
# 66           2016                     2013               2016
# 67           2016                     2001               2016
# 68           2016                     2001               2016
# 69           2012                     2010               2016
# 70           2011                     1995               2011
# 71           2012                     1990               2010
# 72           2014                     1995               2016
# 74           2016                     2005               2015
# 76           2016                     2005               2014
#
#     start_year-check  end_year-check
# 0               True           False
# 2               True            True
# 5              False           False
# 6              False           False
# 7               True            True
# 8              False           False
# 9               True            True
# 10              True            True
# 12              True            True
# 13              True           False
# 15             False            True
# 16             False            True
# 19              True            True
# 20              True           False
# 21              True            True
# 22             False           False
# 23              True            True
# 24              True            True
# 25             False           False
# 26              True            True
# 27             False            True
# 29              True            True
# 30             False            True
# 31              True           False
# 32             False           False
# 33             False           False
# 34             False           False
# 35             False           False
# 36             False            True
# 37             False           False
# 38              True            True
# 39              True            True
# 40             False            True
# 41              True            True
# 42             False           False
# 44              True            True
# 45             False            True
# 47             False            True
# 49              True            True
# 50              True           False
# 51              True           False
# 52              True            True
# 53              True            True
# 54              True            True
# 55              True            True
# 57             False            True
# 58              True           False
# 59             False            True
# 60              True            True
# 61              True           False
# 64             False           False
# 66              True            True
# 67              True            True
# 68             False            True
# 69             False           False
# 70              True            True
# 71              True            True
# 72             False           False
# 74             False            True
# 76              True            True

# %%
df_merge_shortlist['amida_action'] = df_merge_shortlist.apply(lambda x: amida_action(x), axis=1)

# %%
df_merge_shortlist.head()
# Out:
#     id                         title                         slug Site  \
# 0  590                          PEFA                         PEFA   gv
# 2   50   Logistics Performance Index  logistics_performance_index   tc
# 5  147  Public Investment Management                          PIM   gv
# 6  483     Human Resource Management                          HRM   gv
# 7  512       UNCTAD Cyberlaw Tracker      UNCTAD Cyberlaw Tracker   tc
#
#   start_year-clean end_year-clean Start Year Latest Year  start_year-check  \
# 0             2005           2015       2005        2016              True
# 2             2007           2016       2007        2016              True
# 5             2010           2010       1987        2016             False
# 6             2009           2009       1987        2016             False
# 7             2016           2016       2016        2016              True
#
#    end_year-check                                       amida_action
# 0           False  [Gov dataset - For Luis' action] Not updated (...
# 2            True                       Updated. No action required.
# 5           False  [Gov dataset - For Luis' action] Not updated (...
# 6           False  [Gov dataset - For Luis' action] Not updated (...
# 7            True                       Updated. No action required.

# %%
df_merge_shortlist.columns = ['id', 'title', 'slug', 'Site', 'current-start_year', 'current-end_year',
       'ideal-start_year', 'ideal-end_year', 'start_year-check', 'end_year-check',
       'amida_action']

# %%
df_merge_shortlist.to_csv("%s-Check-TC-Data-Update.csv" % date_today, index=False)
df_merge.to_csv("%s-Check-TC-Data-Update-verboseprofile.csv" % date_today, index=False)
